# %%
a={"name":"nn","age":12}
a
# Out:
# {'name': 'nn', 'age': 12}

# %%
a.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
a.items()
# Out:
# dict_items([('name', 'nn'), ('age', 12)])

# %% [markdown]
# ### 哈哈哈

# %%
a={1,2,3,4,5,44}
b={3,4,5,3,2,2234}
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 44, 2234}
